# %%
# gross income by state 2019
import pandas as pd
from splinter import Browser
import time
from bs4 import BeautifulSoup as bs

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
urlIncomeData ="https://worldpopulationreview.com/state-rankings/median-household-income-by-state"
browser.visit(urlIncomeData)

# %%
incomeURL ="https://worldpopulationreview.com/state-rankings/median-household-income-by-state"
table = pd.read_html(incomeURL)

# %%
df = table[0]
df[["State", "Median Household Income"]]
# Out:
#              State Median Household Income
# 0    Washington DC                 $82,604
# 1         Maryland                 $81,868
# 2       New Jersey                 $79,363
# 3           Hawaii                 $78,084
# 4    Massachusetts                 $77,378
# 5           Alaska                 $76,715
# 6      Connecticut                 $76,106
# 7    New Hampshire                 $74,057
# 8         Virginia                 $71,564
# 9       California                 $71,228
# 10      Washington                 $70,116
# 11        Colorado                 $68,811
# 12       Minnesota                 $68,411
# 13            Utah                 $68,374
# 14        Delaware                 $65,627
# 15        New York                 $65,323
# 16        Illinois                 $63,575
# 17    North Dakota                 $63,473
# 18    Rhode Island                 $63,296
# 19         Wyoming                 $62,268
# 20         Vermont                 $60,076
# ...
